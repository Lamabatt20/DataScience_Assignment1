# %% [markdown]
# # **Assignment** # 1

# %% [markdown]
#  **Name:** Lama Batta

# %% [markdown]
# **ID Student:** 1210922

# %% [markdown]
# <span style="color:blue"> **Import Libraries** </span>

# %%
import pandas as pd

# %% [markdown]
# **Load the data set**

# %%
# Read data from csv file
df = pd.read_csv('assignment_1-python.csv')
df
# Out:
#            date      region        city      market  latitude  longitude  \
# 0    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 1    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 2    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 3    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 4    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# ..          ...         ...         ...         ...       ...        ...
# 349  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 350  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 351  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 352  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 353  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
#
#                   category                        commodity   unit priceflag  \
# ...

# %% [markdown]
# <span style="color:red"> **Identify the most expensive vegetables and fruits commodity during this period.** </span>

# %%
# Filter for vegetables and fruits
vegetables_and_fruits=df[df['category']=='vegetables and fruits']
vegetables_and_fruits
# Out:
#            date      region        city      market  latitude  longitude  \
# 23   2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 24   2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 25   2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 26   2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 27   2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# ..          ...         ...         ...         ...       ...        ...
# 349  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 350  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 351  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 352  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 353  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
#
#                   category               commodity unit priceflag pricetype  \
# ...

# %% [markdown]
# <span style="color:blue">This is the result of filtering a dataset for the category Fruits and Vegetables, where there are 75 rows containing this category.  </span>

# %%
#find the most expensive price vegetables and fruits 

most_expensive=vegetables_and_fruits[vegetables_and_fruits['usdprice']==vegetables_and_fruits['usdprice'].max()].iloc[0]
print(f"Commodity: {most_expensive['commodity']}, Price: {most_expensive['usdprice']}")
# Out:
# Commodity: Apples (red), Price: 1.7703

# %% [markdown]
# <span style="color:blue">This is the result of the most expensive commodity of vegetables and fruits, which is apples, and its value price is 1.7703
#   </span>

# %% [markdown]
# <span style="color:red"> **Add a new column named currency_rate that captures the exchange rate between the local currency and the US dollar (USD).** </span>

# %%
#create new column currency_rate
df['currency_rate']=df['price']/df['usdprice']
df
# Out:
#            date      region        city      market  latitude  longitude  \
# 0    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 1    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 2    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 3    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 4    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# ..          ...         ...         ...         ...       ...        ...
# 349  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 350  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 351  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 352  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 353  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
#
#                   category                        commodity   unit priceflag  \
# ...

# %% [markdown]
# <span style="color:blue">This is the dataset after we calculated the exchange rate between the local currency and the US dollar (USD) for each row and then created a new column named currency_rate containing these values.
#   </span>

# %% [markdown]
# <span style="color:red"> **Create a new column called unified_price that represents the price in USD per kilogram for commodities measured by weight and the price per liter for commodities measured by volume.** </span>

# %%
# Custom function to calculate  unified_price
def unified_price(row):
    #split unit column for each row 
    Value_unit= row['unit'].split()
    value = 1.0  
    if len(Value_unit) > 1 and Value_unit[0].isdigit():
        value = float(Value_unit[0]) 
    elif len(Value_unit) == 1 and Value_unit[0].isdigit():
        value = float(Value_unit[0])
        
    if 'KG' in row['unit']:
        return row['usdprice'] /value
    elif 'G' in row['unit']:
        return row['usdprice']  /(value/ 1000 )
    elif 'L' in row['unit']:
        return row['usdprice'] /value 
    elif 'Cubic meter' in row['unit']:
        return row['usdprice'] /(value * 1000 )
    else:
        return None
# Applying the function to each row
df['unified_price'] = df.apply(unified_price, axis=1)
df
# Out:
#            date      region        city      market  latitude  longitude  \
# 0    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 1    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 2    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 3    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 4    2022-01-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# ..          ...         ...         ...         ...       ...        ...
# 349  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 350  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 351  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 352  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
# 353  2022-12-15  Gaza Strip  Kan Younis  Gaza Strip  31.34611   34.32573
#
#                   category                        commodity   unit priceflag  \
# ...

# %% [markdown]
# <span style="color:blue">This is the dataset after we calculated the unified price, so we created a new column called unified_price and the results were as follows: price in USD per kilogram, price per liter for each commodity measured by weight or volume
#   </span>

# %% [markdown]
# <span style="color:red"> **Using the unified_price, find the maximum price reached during this period and for which commodity for both:
# commodities measured by weight
# commodities measured by volume** </span>

# %%
#find the maximum price for each commodity measured by weight
max_unified_price = df[(df['unit'] == 'KG') | (df['unit'] == 'G')]['unified_price'].max() 
maximum_weight = df[df['unified_price'] == max_unified_price].iloc[0]
print(f"Commodity: {maximum_weight['commodity']}, Unified Price: {maximum_weight['unified_price']}")
# Out:
# Commodity: Meat (goat, with bones), Unified Price: 17.3144

# %% [markdown]
# <span style="color:blue">This is the result of the maximum price commodity measured by weight, which is Meat (goat, with bones),and its value Unified Price: 17.3144 which is the maximum price of commodities measured by weight.
#   </span>

# %%
#find the maximum price for each commodity measured by volume
max_unified_price = df[(df['unit'] == 'L') | (df['unit'] == 'Cubic meter')]['unified_price'].max()
maximum_volume = df[df['unified_price'] == max_unified_price].iloc[0]
print(f"Commodity: {maximum_volume['commodity']}, Unified Price: {maximum_volume['unified_price']}")
# Out:
# Commodity: Fuel (petrol-gasoline), Unified Price: 2.0459

# %% [markdown]
# <span style="color:blue">This is the result of the maximum price commodity measured by volume, which is Fuel (petrol-gasoline),and its value Unified Price:  2.0459 which is the maximum price of commodities measured by volume.
#   </span>
